# %%
#subscripting
print("hello"[0:3])
print("deborah"[::-1])
# Out:
# hel
# harobed

# %%
#string
print("234"+"3424")
# Out:
# 2343424

# %%
#integer
print(35+13)
# Out:
# 48

# %%
#large integers
print(123_233_456_66)
# Out:
# 12323345666

# %%
#float
print(3.1456)
# Out:
# 3.1456

# %%
#boolean
print(True)
print(False)
# Out:
# True
# False

# %%
#type error
print(len("234"))
print(len(234))# len doesn't work for the int value . which cause the type erroe
# Out:
# 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 #type error
#       2 print(len("234"))
# ----> 3 print(len(234))# len doesn't work for the int value . which cause the type erroe
#
# TypeError: object of type 'int' has no len()

# %%
print(type(23))#helps you tell the type of data
print(type(3.14))
print(type("number"))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
#typeconversion
print(int("123")+int("342"))
print(int("abc")+int("abc"))# this would result the value error since you can't able convert a string into an integer
# Out:
# 465
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 3
#       1 #typeconversion
#       2 print(int("123")+int("342"))
# ----> 3 print(int("abc")+int("abc"))
#
# ValueError: invalid literal for int() with base 10: 'abc'

# %%
#question to correct the code.
print("length of your name: "+len(input("enter your name"))
# Out:
#   Cell In[22], line 1
#     print("enter your name: "+len(input("enter your name"))
#                                                            ^
# _IncompleteInputError: incomplete input

# %%
a=input("enter your name")
print("the length of your name is: ",len(a))
# Out:
# enter your name charu
# the length of your name is:  5

# %%
print(6/3)
# Out:
# 2.0

# %%
print(int(6/3))
# Out:
# 2

# %%
print(10+3)
print(10-3)
print(10*3)
print(10/3)
print(10//3)
print(10**3)
print(10%3)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1000
# 1

# %%
print(3*3+3/3-3)
print(3*(3+3)/3-3)
# Out:
# 7.0
# 3.0

# %%
#question : find the bmi value.
weight=69
height=1.73
bmi=weight/(height**2)
print("the bmi value is: ",round(bmi,5))
# Out:
# the bmi value is:  23.05456

# %%
#assignment operator
a=0
a=+1
print(a)
a-=1
print(a)
# Out:
# 1
# 0

# %%
#f--string(used to combine multiple datatype of value to a string.
a=3
name="raju"
height=1.75
eligiblity=True
c=(f"the value of a={a},your name is:{name}, your height is:{height},are u eligible:{eligiblity}")
print(c)
print(type(c))
# Out:
# the value of a=3,your name is:raju, your height is:1.75,are u eligible:True
# <class 'str'>

# %%
print(""",-----------------------------.----------------------------------.
|                             |                                  |
|    .    .    ,---------     |     ------------------------.    |
|    |    |    |              |                             |    |
|    |    `----"--------------'    ,-------------------.    |    |
|    |                             |                   |    |    |
|    :--------------.--------------"----     ,---------:    |    |
|    |              |                        |         |    |    |
|    :---------     |    .    ,---------.    |    .    |    `----:
|    |              |    |    |         |    |    |    |         |
|    |     ---------'    |    :----     |    |    |    |    .    |
|    |                   |    |         |    |    |    |    |    |
|    `-------------------'    |     ----'    |    |    |    |    |
|                             |              |    |    |    |    |
:--------------.---------.    :--------------'    |    :----'    |
|              |         |    |                   |    |         |
|    .    .    |    .    |    |    ,--------------:    `----     |
|    |    |    |    |    |    |    |              |              |
|    |    |    "    |    |    |    |     ---------"---------.    |
|    |    |         |    |    |    |                        |    |
|    |    `---------"----'    |    |    ,---------.    .    |    |
|    |                        |    |    |         |    |    |    |
|    :---------.--------------:    |    |    .    |    |    |    |
|    |         | X            |    |    |    |    |    |    |    |
|    "    .    `---------     |    |    `----'    |    `----'    |
|         |                   |    |              |              |
`---------"-------------------'    `--------------"--------------' 
""")
print("WELCOME TO THE TREASURE ISLAND !")
print("your mission is to find the treasure")
a=input("where do you wanna go? (left/right)")
if(a=='left'):
    print("you are dead my friend")
elif(a=='right'):
    print("go ahead my soldier")
    b=input("you saw a boat(take/ignore)")
    if(b=='ignore'):
        print("you are dead my friend")
    elif(b=='take'):
        print("go ahead my soldier")
        c=input( "choose a color:(r/y/g)") 
        if(c=='r'):
            print("you are dead red flag")
        elif(c=='y'):
            print("we don't encourge mixed signals , you are dead .")
        elif(c=='g'):
            print(" you the won!, green flag ")
else:
    print("invalid input")
# Out:
# ,-----------------------------.----------------------------------.
# |                             |                                  |
# |    .    .    ,---------     |     ------------------------.    |
# |    |    |    |              |                             |    |
# |    |    `----"--------------'    ,-------------------.    |    |
# |    |                             |                   |    |    |
# |    :--------------.--------------"----     ,---------:    |    |
# |    |              |                        |         |    |    |
# |    :---------     |    .    ,---------.    |    .    |    `----:
# |    |              |    |    |         |    |    |    |         |
# |    |     ---------'    |    :----     |    |    |    |    .    |
# |    |                   |    |         |    |    |    |    |    |
# |    `-------------------'    |     ----'    |    |    |    |    |
# |                             |              |    |    |    |    |
# ...

# %%
print(""",-----------------------------.----------------------------------.
|                             |                                  |
|    .    .    ,---------     |     ------------------------.    |
|    |    |    |              |                             |    |
|    |    `----"--------------'    ,-------------------.    |    |
|    |                             |                   |    |    |
|    :--------------.--------------"----     ,---------:    |    |
|    |              |                        |         |    |    |
|    :---------     |    .    ,---------.    |    .    |    `----:
|    |              |    |    |         |    |    |    |         |
|    |     ---------'    |    :----     |    |    |    |    .    |
|    |                   |    |         |    |    |    |    |    |
|    `-------------------'    |     ----'    |    |    |    |    |
|                             |              |    |    |    |    |
:--------------.---------.    :--------------'    |    :----'    |
|              |         |    |                   |    |         |
|    .    .    |    .    |    |    ,--------------:    `----     |
|    |    |    |    |    |    |    |              |              |
|    |    |    "    |    |    |    |     ---------"---------.    |
|    |    |         |    |    |    |                        |    |
|    |    `---------"----'    |    |    ,---------.    .    |    |
|    |                        |    |    |         |    |    |    |
|    :---------.--------------:    |    |    .    |    |    |    |
|    |         | X            |    |    |    |    |    |    |    |
|    "    .    `---------     |    |    `----'    |    `----'    |
|         |                   |    |              |              |
`---------"-------------------'    `--------------"--------------' 
""")
print("WELCOME TO THE TREASURE ISLAND !")
print("your mission is to find the treasure")
a=input("where do you wanna go? (left/right)").lower()
if(a=='left'):
    print("you are dead my friend")
elif(a=='right'):
    print("go ahead my soldier")
    b=input("you saw a boat(take/ignore)")
    if(b=='ignore'):
        print("you are dead my friend")
    elif(b=='take'):
        print("go ahead my soldier")
        c=input( "choose a color:(r/y/g)") 
        if(c=='r'):
            print("you are dead red flag")
        elif(c=='y'):
            print("we don't encourge mixed signals , you are dead .")
        elif(c=='g'):
            print(" you the won!, green flag ")
else:
    print("invalid input")
# Out:
# ,-----------------------------.----------------------------------.
# |                             |                                  |
# |    .    .    ,---------     |     ------------------------.    |
# |    |    |    |              |                             |    |
# |    |    `----"--------------'    ,-------------------.    |    |
# |    |                             |                   |    |    |
# |    :--------------.--------------"----     ,---------:    |    |
# |    |              |                        |         |    |    |
# |    :---------     |    .    ,---------.    |    .    |    `----:
# |    |              |    |    |         |    |    |    |         |
# |    |     ---------'    |    :----     |    |    |    |    .    |
# |    |                   |    |         |    |    |    |    |    |
# |    `-------------------'    |     ----'    |    |    |    |    |
# |                             |              |    |    |    |    |
# ...

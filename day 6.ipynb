# %%
#functions,code blocks and while loops
#1. functions (built-in)
print("hello")
a=len("sanju")
print(a)
# Out:
# hello
# 5

# %%
#creating our own function
#"def" is the key word for defining the function
# so inorder to execute the function we need to call the function
#for example
def tree():
    print("pine")
    print("coconut")
tree()
# Out:
# pine
# coconut

# %%
#playing reeborg's world game

# %%
#indentation

# %%
#while loop
# while <conditon-true>:
      #executes.... when the condition becomes false the loop end.

# %%
 # day 5 final project is done in reeborg's world game

# %%
# condition statements
#if -else condition
water_level=int(input())
if (water_level>90):
    print("start drain the water")
else:
    print("continue the flow of water")
# Out:
#  5
# continue the flow of water

# %%
# condition statements
#if -else condition
water_level=int(input())
if (water_level>90):
    print("start drain the water")
else:
    print("continue the flow of water")
# Out:
#  100
# start drain the water

# %%
print("welcome to the roller coaster !")
height=int(input("enter your height in cm"))
if (height>=120):#conditional operator
    print("have a wonderful roller coaster right")
else:
    print("sorry,due to safety concern you aren't eligible")
# Out:
# welcome to the roller coaster !
# enter your height in cm 120
# have a wonderful roller coaster right

# %%
#modulo operator - give the remainder of value
print(10%3)
# Out:
# 1

# %%
#odd or even
a=int(input("enter a number"))
if(a%2==0):
    print("it's even")
else:
    print("it's odd")
# Out:
# enter a number 43
# it's odd

# %%
#nested if and elif statement and multiple if's
print("welcome to the roller coaster !")
height=int(input("enter your height in cm"))
if (height>=120):#conditional operator
    age=int(input("enter your age"))
    if(age<12):
        bill=2
        print("pay:$ ",bill)
    elif(age>=12 and age<=18):#and is for comparing conditions don't confuse it with  '&'. that is a bitwise operator.
        bill=7
        print("pay:$ ",bill)
    elif(age>45 and age<55):
        bill=0
        print("free ticket")
    else:
        bill=12
        print("pay:$ ",bill)
        
    if not(age>45 and age<55):
        photo=input("wanna have photo? (y/n):")
        if(photo=='y'):
             bill+=3
    else:
        print("your fee for photo is also free sir")
            
    print(bill)
    
    
else:
    print("sorry,due to safety concern you aren't eligible")
# Out:
# welcome to the roller coaster !
# enter your height in cm 170
# enter your age 52
# free ticket
# your fee for photo is also free sir
# 0

# %%
# pizza bill
print(" hey! welcome to the pizza hunt")
extra_chesse=15
pizza=input("what pizza size you prefer?(small /medium/large)")
if(pizza=='small'):
    bill=50
    print("bill:$ ",bill)
elif(pizza=='medium'):
    bill=75
    print("bill:$ ",bill)
elif(pizza=='large'):
    bill=100
    print("bill:$ ",bill)
a=input("do you wanna have pepproni on your pizza?(y/n)")
if(a=='y'):
    bill+=20
b=input("wanna have extra cheese?(y/n)")
if(b=='y'):
    bill+=15

print("your total bill is:$ ",bill)
# Out:
#  hey! welcome to the pizza hunt
# what pizza size you prefer?(small /medium/large) large
# bill:$  100
# do you wanna have pepproni on your pizza?(y/n) n
# wanna have extra cheese?(y/n) y
# your total bill is:$  115

# %%
# logical operator( and, or, not)

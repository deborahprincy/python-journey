# %%
print("hello guyss welcome to band name generator")
name=input("enter your name")
a=input("enter the city you grew up in")
b=input("enter your pet name")
print(name+"!  your band name is: "+a+ " "+b)
# Out:
# hello guyss welcome to band name generator
# enter your name deborah
# enter the city you grew up in chennai
# enter your pet name bobby
# deborah!  your band name is: chennai bobby

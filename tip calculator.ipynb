# %%
print("welcome to the tip calculator!")
a=float(input("what was your total bill?"))
print(a)
b=float(input("how much percent would you like to tip ?"))
print(b)
c=float(input("how much people would split the bill ?"))
print(c)
d=((a+(a*(b/100)))/c)
print("each person should suppose to pay is: ",round(d,2))
# Out:
# welcome to the tip calculator!
# what was your total bill? 123.23
# 123.23
# how much percent would you like to tip ? 24.2
# 24.2
# how much people would split the bill ? 3
# 3.0
# each person should suppose to pay is:  51.02

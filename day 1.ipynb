# %%
#1.how to just print 
print("hello!")
# Out:
# hello!

# %%
#how to print multi line code (use"\n")
print("hello print\nhello")
# Out:
# hello print
# hello

# %%
#2.concatenation
print("hello"+"deborah")
# Out:
# hellodeborah

# %%
print("hello"+" "+"princy")

# %%
#3.debugging

# %%
#4. use of input function
input("enter a number")
print("hello"+" "+input("enter your name")+"!")
# Out:
# enter a number 7
# enter your name deborah
# hello deborah!

# %%
# if you don't understand how the structure of the python code works give it try for"thonny")

# %%
# use ctrl+/ is you want turn the code into comment

# %%
print(len(input("whats your name")))
# Out:
# whats your name debo
# 4

# %%
name=input("enter your name")
length=len(name)
print(length)
# Out:
# enter your name jerome
# 6

# %%
a="charu"
b="latha"
#inorder to swap the content in the variables i use "temp " which stands for temporary

temp=a
a=b
b=temp
print(a,b)
# Out:
# latha charu
